# %%
import numpy as np
import pandas as pd
data=pd.read_csv("heart_disease.csv")
data.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
data.tail()
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
#      Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 9995                   No       No  18.788791                 Yes  ...
# 9996                   No       No  31.856801                 Yes  ...
# 9997                   No      Yes  26.899911                  No  ...
# 9998                   No      Yes  34.964026                 Yes  ...
# 9999                  Yes      Yes  25.111295                  No  ...
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
data.isnull()
# Out:
#         Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  \
# 0     False   False           False              False            False
# 1     False   False           False              False            False
# 2     False   False           False              False            False
# 3     False   False           False              False            False
# 4     False   False           False              False            False
# ...     ...     ...             ...                ...              ...
# 9995  False   False           False              False            False
# 9996  False   False           False              False            False
# 9997  False   False           False              False            False
# 9998  False   False           False              False            False
# 9999  False   False           False              False            False
#
#       Smoking  Family Heart Disease  Diabetes    BMI  High Blood Pressure  \
# ...

# %%
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Gender"]=labelencoder.fit_transform(data["Gender"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0       1           153.0              155.0            High     Yes
# 1     69.0       0           146.0              286.0            High      No
# 2     46.0       1           126.0              216.0             Low      No
# 3     32.0       0           122.0              293.0            High     Yes
# 4     60.0       1           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0       0           136.0              243.0          Medium     Yes
# 9996  38.0       1           172.0              154.0          Medium      No
# 9997  73.0       1           152.0              201.0            High     Yes
# 9998  23.0       1           142.0              299.0             Low     Yes
# 9999  38.0       0           128.0              193.0          Medium     Yes
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Smoking"]=labelencoder.fit_transform(data["Smoking"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease Diabetes        BMI High Blood Pressure  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Diabetes"]=labelencoder.fit_transform(data["Diabetes"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI High Blood Pressure  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Heart Disease Status"]=labelencoder.fit_transform(data["Heart Disease Status"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI High Blood Pressure  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                       29
# Gender                     0
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                    0
# Family Heart Disease      21
# Diabetes                   0
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Alcohol Consumption"]=labelencoder.fit_transform(data["Alcohol Consumption"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI High Blood Pressure  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["High Blood Pressure"]=labelencoder.fit_transform(data["High Blood Pressure"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["High LDL Cholesterol"]=labelencoder.fit_transform(data["High LDL Cholesterol"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
labelencoder= LabelEncoder()
data["Stress Level"]=labelencoder.fit_transform(data["Stress Level"])
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# ...

# %%
a=data["Age"].mean()
a
# Out:
# 49.296259151539466

# %%
b=data["Blood Pressure"].mean()
b
# Out:
# 149.75773970544034

# %%
c=data["Cholesterol Level"].mean()
c
# Out:
# 225.42557673019058

# %%
d=data["Alcohol Consumption"].mode()
d
# Out:
# 0    3
# Name: Alcohol Consumption, dtype: int32

# %%
e=data["Sleep Hours"].mean()
e
# Out:
# 6.9913294463426

# %%
f=data["High Blood Pressure"].mode()
f
# Out:
# 0    1
# Name: High Blood Pressure, dtype: int32

# %%
g=data["High LDL Cholesterol"].mode()
g
# Out:
# 0    0
# Name: High LDL Cholesterol, dtype: int32

# %%
h=data["Stress Level"].mode()
h
# Out:
# 0    2
# Name: Stress Level, dtype: int32

# %%
data["Age"].fillna(a, inplace=True)
data["Blood Pressure"].fillna(b, inplace=True)
data["Cholesterol Level"].fillna(c, inplace=True)
data["Alcohol Consumption"].fillna(d, inplace=True)
data["Sleep Hours"].fillna(e, inplace=True)
data["High Blood Pressure"].fillna(f, inplace=True)
data["High LDL Cholesterol"].fillna(g, inplace=True)
data["Stress Level"].fillna(h, inplace=True)
# Out:
# C:\Users\vishal\AppData\Local\Temp\ipykernel_23196\1718027355.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Age"].fillna(a, inplace=True)
# C:\Users\vishal\AppData\Local\Temp\ipykernel_23196\1718027355.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Blood Pressure           0
# Cholesterol Level        0
# Exercise Habits         25
# Smoking                  0
# Family Heart Disease    21
# Diabetes                 0
# BMI                     22
# High Blood Pressure      0
# Low HDL Cholesterol     25
# High LDL Cholesterol     0
# Alcohol Consumption      0
# Stress Level             0
# Sleep Hours              0
# Sugar Consumption       30
# Triglyceride Level      26
# Fasting Blood Sugar     22
# CRP Level               26
# Homocysteine Level      20
# Heart Disease Status     0
# dtype: int64

# %%
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0     56.0       1           153.0              155.0            High
# 1     69.0       0           146.0              286.0            High
# 2     46.0       1           126.0              216.0             Low
# 3     32.0       0           122.0              293.0            High
# 4     60.0       1           166.0              242.0             Low
# ...    ...     ...             ...                ...             ...
# 9995  25.0       0           136.0              243.0          Medium
# 9996  38.0       1           172.0              154.0          Medium
# 9997  73.0       1           152.0              201.0            High
# 9998  23.0       1           142.0              299.0             Low
# 9999  38.0       0           128.0              193.0          Medium
#
#       Smoking Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# ...

# %%
X=data.drop(["Exercise Habits","Family Heart Disease","BMI","Low HDL Cholesterol","Sugar Consumption","Triglyceride Level","Fasting Blood Sugar","CRP Level","Homocysteine Level","Heart Disease Status"],axis=1)
Y=data["Heart Disease Status"]

# %%
X
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level  Smoking  Diabetes  \
# 0     56.0       1           153.0              155.0        1         0
# 1     69.0       0           146.0              286.0        0         1
# 2     46.0       1           126.0              216.0        0         0
# 3     32.0       0           122.0              293.0        1         0
# 4     60.0       1           166.0              242.0        1         1
# ...    ...     ...             ...                ...      ...       ...
# 9995  25.0       0           136.0              243.0        1         0
# 9996  38.0       1           172.0              154.0        0         0
# 9997  73.0       1           152.0              201.0        1         1
# 9998  23.0       1           142.0              299.0        1         1
# 9999  38.0       0           128.0              193.0        1         1
#
#       High Blood Pressure  High LDL Cholesterol  Alcohol Consumption  \
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: Heart Disease Status, Length: 10000, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level  Smoking  Diabetes  \
# 9254  78.0       1           140.0              289.0        1         0
# 1561  64.0       1           143.0              203.0        1         1
# 1670  18.0       0           147.0              161.0        1         1
# 6087  24.0       0           145.0              195.0        1         0
# 6669  49.0       1           157.0              291.0        1         1
# ...    ...     ...             ...                ...      ...       ...
# 5734  37.0       1           168.0              221.0        0         0
# 5191  54.0       0           156.0              261.0        0         0
# 5390  49.0       0           144.0              228.0        0         0
# 860   22.0       0           137.0              238.0        1         0
# 7270  66.0       0           135.0              287.0        1         0
#
#       High Blood Pressure  High LDL Cholesterol  Alcohol Consumption  \
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(model,"heart_disease.pkl")
# Out:
# ['heart_disease.pkl']

# %%
import joblib
load=joblib.load("heart_disease.pkl")
y_pred=load.predict([[73.0,1,152.0,201.0,1,0,0,1,0,1,4.436762,]])
y_pred
# Out:
# C:\Users\vishal\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.20161893])

# %%
Y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 6412    0
# 8285    1
# 7853    0
# 1095    0
# 6929    0
# Name: Heart Disease Status, Length: 2000, dtype: int32

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0.18921337, 0.20261632, 0.17577274, ..., 0.17546414, 0.22737075,
#        0.20598244])

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# C:\Users\vishal\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import joblib
load=joblib.load("heart_disease.pkl")
y_pred=load.predict([[73.0,1,152.0,201.0,1,0,0,1,0,1,4.436762,]])
y_pred
# Out:
# C:\Users\vishal\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.20161893])

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 6412    0
# 8285    1
# 7853    0
# 1095    0
# 6929    0
# Name: Heart Disease Status, Length: 2000, dtype: int32

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test, y_pred) 
accuracy
# Out:
# 0.8065

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(Y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Reds)
plt.title("Confusion Matrix")
plt.show()
