# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1,2])
y = np.array([1, 2,3])

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1,2,3,4])
y = np.array([1, 2,4,8,3])

plt.plot(x, y)
plt.show()
